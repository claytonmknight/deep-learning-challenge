# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
print(application_df.nunique())
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_type_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 500
application_types_to_replace = application_type_counts[application_type_counts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts_filtered = classification_counts[classification_counts > 1]
print(classification_counts_filtered)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value_class = 1000
classifications_to_replace = classification_counts[classification_counts < cutoff_value_class].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_encoded = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_df_encoded.drop(columns=['IS_SUCCESSFUL']).values
y = application_df_encoded['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, input_dim=input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 804/804 - 3s - loss: 0.5726 - accuracy: 0.7188 - 3s/epoch - 4ms/step
# Epoch 2/100
# 804/804 - 2s - loss: 0.5565 - accuracy: 0.7285 - 2s/epoch - 3ms/step
# Epoch 3/100
# 804/804 - 1s - loss: 0.5528 - accuracy: 0.7293 - 1s/epoch - 2ms/step
# Epoch 4/100
# 804/804 - 1s - loss: 0.5504 - accuracy: 0.7303 - 1s/epoch - 1ms/step
# Epoch 5/100
# 804/804 - 1s - loss: 0.5492 - accuracy: 0.7315 - 1s/epoch - 1ms/step
# Epoch 6/100
# 804/804 - 1s - loss: 0.5482 - accuracy: 0.7318 - 1s/epoch - 1ms/step
# Epoch 7/100
# 804/804 - 1s - loss: 0.5478 - accuracy: 0.7321 - 1s/epoch - 2ms/step
# Epoch 8/100
# 804/804 - 1s - loss: 0.5468 - accuracy: 0.7318 - 1s/epoch - 1ms/step
# Epoch 9/100
# 804/804 - 1s - loss: 0.5456 - accuracy: 0.7315 - 1s/epoch - 1ms/step
# Epoch 10/100
# 804/804 - 1s - loss: 0.5460 - accuracy: 0.7332 - 1s/epoch - 1ms/step
# Epoch 11/100
# 804/804 - 2s - loss: 0.5451 - accuracy: 0.7338 - 2s/epoch - 2ms/step
# Epoch 12/100
# 804/804 - 2s - loss: 0.5449 - accuracy: 0.7340 - 2s/epoch - 2ms/step
# Epoch 13/100
# 804/804 - 2s - loss: 0.5444 - accuracy: 0.7340 - 2s/epoch - 2ms/step
# Epoch 14/100
# 804/804 - 2s - loss: 0.5442 - accuracy: 0.7344 - 2s/epoch - 2ms/step
# Epoch 15/100
# 804/804 - 1s - loss: 0.5439 - accuracy: 0.7351 - 1s/epoch - 2ms/step
# Epoch 16/100
# 804/804 - 1s - loss: 0.5430 - accuracy: 0.7348 - 1s/epoch - 2ms/step
# Epoch 17/100
# 804/804 - 1s - loss: 0.5429 - accuracy: 0.7359 - 1s/epoch - 2ms/step
# Epoch 18/100
# 804/804 - 1s - loss: 0.5427 - accuracy: 0.7356 - 1s/epoch - 2ms/step
# Epoch 19/100
# 804/804 - 2s - loss: 0.5427 - accuracy: 0.7357 - 2s/epoch - 2ms/step
# Epoch 20/100
# 804/804 - 1s - loss: 0.5420 - accuracy: 0.7370 - 1s/epoch - 1ms/step
# Epoch 21/100
# 804/804 - 1s - loss: 0.5420 - accuracy: 0.7362 - 1s/epoch - 2ms/step
# Epoch 22/100
# 804/804 - 2s - loss: 0.5417 - accuracy: 0.7367 - 2s/epoch - 2ms/step
# Epoch 23/100
# 804/804 - 2s - loss: 0.5410 - accuracy: 0.7360 - 2s/epoch - 2ms/step
# Epoch 24/100
# 804/804 - 2s - loss: 0.5416 - accuracy: 0.7371 - 2s/epoch - 2ms/step
# Epoch 25/100
# 804/804 - 2s - loss: 0.5404 - accuracy: 0.7373 - 2s/epoch - 2ms/step
# Epoch 26/100
# 804/804 - 1s - loss: 0.5411 - accuracy: 0.7368 - 1s/epoch - 1ms/step
# Epoch 27/100
# 804/804 - 1s - loss: 0.5408 - accuracy: 0.7367 - 1s/epoch - 1ms/step
# Epoch 28/100
# 804/804 - 1s - loss: 0.5402 - accuracy: 0.7365 - 1s/epoch - 2ms/step
# Epoch 29/100
# 804/804 - 1s - loss: 0.5403 - accuracy: 0.7360 - 1s/epoch - 1ms/step
# Epoch 30/100
# 804/804 - 1s - loss: 0.5396 - accuracy: 0.7372 - 1s/epoch - 1ms/step
# Epoch 31/100
# 804/804 - 1s - loss: 0.5396 - accuracy: 0.7371 - 1s/epoch - 1ms/step
# Epoch 32/100
# 804/804 - 1s - loss: 0.5394 - accuracy: 0.7371 - 1s/epoch - 2ms/step
# Epoch 33/100
# 804/804 - 1s - loss: 0.5395 - accuracy: 0.7366 - 1s/epoch - 2ms/step
# Epoch 34/100
# 804/804 - 2s - loss: 0.5394 - accuracy: 0.7374 - 2s/epoch - 2ms/step
# Epoch 35/100
# 804/804 - 2s - loss: 0.5386 - accuracy: 0.7370 - 2s/epoch - 2ms/step
# Epoch 36/100
# 804/804 - 2s - loss: 0.5393 - accuracy: 0.7383 - 2s/epoch - 2ms/step
# Epoch 37/100
# 804/804 - 1s - loss: 0.5388 - accuracy: 0.7383 - 1s/epoch - 2ms/step
# Epoch 38/100
# 804/804 - 1s - loss: 0.5385 - accuracy: 0.7378 - 1s/epoch - 2ms/step
# Epoch 39/100
# 804/804 - 1s - loss: 0.5386 - accuracy: 0.7377 - 1s/epoch - 1ms/step
# Epoch 40/100
# 804/804 - 1s - loss: 0.5385 - accuracy: 0.7388 - 1s/epoch - 1ms/step
# Epoch 41/100
# 804/804 - 1s - loss: 0.5386 - accuracy: 0.7377 - 1s/epoch - 1ms/step
# Epoch 42/100
# 804/804 - 1s - loss: 0.5383 - accuracy: 0.7374 - 1s/epoch - 2ms/step
# Epoch 43/100
# 804/804 - 1s - loss: 0.5375 - accuracy: 0.7379 - 1s/epoch - 2ms/step
# Epoch 44/100
# 804/804 - 1s - loss: 0.5382 - accuracy: 0.7387 - 1s/epoch - 2ms/step
# Epoch 45/100
# 804/804 - 2s - loss: 0.5374 - accuracy: 0.7389 - 2s/epoch - 2ms/step
# Epoch 46/100
# 804/804 - 2s - loss: 0.5374 - accuracy: 0.7392 - 2s/epoch - 2ms/step
# Epoch 47/100
# 804/804 - 2s - loss: 0.5373 - accuracy: 0.7377 - 2s/epoch - 2ms/step
# Epoch 48/100
# 804/804 - 1s - loss: 0.5375 - accuracy: 0.7379 - 1s/epoch - 1ms/step
# Epoch 49/100
# 804/804 - 1s - loss: 0.5372 - accuracy: 0.7380 - 1s/epoch - 1ms/step
# Epoch 50/100
# 804/804 - 1s - loss: 0.5372 - accuracy: 0.7381 - 1s/epoch - 2ms/step
# Epoch 51/100
# 804/804 - 1s - loss: 0.5366 - accuracy: 0.7386 - 1s/epoch - 2ms/step
# Epoch 52/100
# 804/804 - 1s - loss: 0.5372 - accuracy: 0.7391 - 1s/epoch - 2ms/step
# Epoch 53/100
# 804/804 - 1s - loss: 0.5370 - accuracy: 0.7388 - 1s/epoch - 2ms/step
# Epoch 54/100
# 804/804 - 1s - loss: 0.5370 - accuracy: 0.7388 - 1s/epoch - 2ms/step
# Epoch 55/100
# 804/804 - 1s - loss: 0.5367 - accuracy: 0.7388 - 1s/epoch - 2ms/step
# Epoch 56/100
# 804/804 - 2s - loss: 0.5363 - accuracy: 0.7395 - 2s/epoch - 2ms/step
# Epoch 57/100
# 804/804 - 2s - loss: 0.5369 - accuracy: 0.7392 - 2s/epoch - 2ms/step
# Epoch 58/100
# 804/804 - 2s - loss: 0.5362 - accuracy: 0.7395 - 2s/epoch - 2ms/step
# Epoch 59/100
# 804/804 - 1s - loss: 0.5367 - accuracy: 0.7390 - 1s/epoch - 1ms/step
# Epoch 60/100
# 804/804 - 1s - loss: 0.5362 - accuracy: 0.7399 - 1s/epoch - 1ms/step
# Epoch 61/100
# 804/804 - 1s - loss: 0.5363 - accuracy: 0.7390 - 1s/epoch - 2ms/step
# Epoch 62/100
# 804/804 - 1s - loss: 0.5359 - accuracy: 0.7397 - 1s/epoch - 2ms/step
# Epoch 63/100
# 804/804 - 1s - loss: 0.5361 - accuracy: 0.7386 - 1s/epoch - 2ms/step
# Epoch 64/100
# 804/804 - 1s - loss: 0.5359 - accuracy: 0.7400 - 1s/epoch - 2ms/step
# Epoch 65/100
# 804/804 - 1s - loss: 0.5358 - accuracy: 0.7393 - 1s/epoch - 2ms/step
# Epoch 66/100
# 804/804 - 1s - loss: 0.5358 - accuracy: 0.7396 - 1s/epoch - 2ms/step
# Epoch 67/100
# 804/804 - 2s - loss: 0.5355 - accuracy: 0.7392 - 2s/epoch - 2ms/step
# Epoch 68/100
# 804/804 - 2s - loss: 0.5359 - accuracy: 0.7395 - 2s/epoch - 2ms/step
# Epoch 69/100
# 804/804 - 2s - loss: 0.5354 - accuracy: 0.7395 - 2s/epoch - 2ms/step
# Epoch 70/100
# 804/804 - 1s - loss: 0.5355 - accuracy: 0.7396 - 1s/epoch - 2ms/step
# Epoch 71/100
# 804/804 - 1s - loss: 0.5355 - accuracy: 0.7391 - 1s/epoch - 1ms/step
# Epoch 72/100
# 804/804 - 1s - loss: 0.5357 - accuracy: 0.7400 - 1s/epoch - 1ms/step
# Epoch 73/100
# 804/804 - 1s - loss: 0.5353 - accuracy: 0.7402 - 1s/epoch - 1ms/step
# Epoch 74/100
# 804/804 - 1s - loss: 0.5351 - accuracy: 0.7389 - 1s/epoch - 1ms/step
# Epoch 75/100
# 804/804 - 1s - loss: 0.5349 - accuracy: 0.7398 - 1s/epoch - 1ms/step
# Epoch 76/100
# 804/804 - 1s - loss: 0.5357 - accuracy: 0.7396 - 1s/epoch - 2ms/step
# Epoch 77/100
# 804/804 - 1s - loss: 0.5353 - accuracy: 0.7397 - 1s/epoch - 2ms/step
# Epoch 78/100
# 804/804 - 3s - loss: 0.5353 - accuracy: 0.7401 - 3s/epoch - 3ms/step
# Epoch 79/100
# 804/804 - 3s - loss: 0.5353 - accuracy: 0.7399 - 3s/epoch - 4ms/step
# Epoch 80/100
# 804/804 - 2s - loss: 0.5349 - accuracy: 0.7395 - 2s/epoch - 3ms/step
# Epoch 81/100
# 804/804 - 2s - loss: 0.5346 - accuracy: 0.7393 - 2s/epoch - 3ms/step
# Epoch 82/100
# 804/804 - 3s - loss: 0.5348 - accuracy: 0.7396 - 3s/epoch - 3ms/step
# Epoch 83/100
# 804/804 - 2s - loss: 0.5347 - accuracy: 0.7387 - 2s/epoch - 3ms/step
# Epoch 84/100
# 804/804 - 4s - loss: 0.5343 - accuracy: 0.7397 - 4s/epoch - 5ms/step
# Epoch 85/100
# 804/804 - 3s - loss: 0.5351 - accuracy: 0.7392 - 3s/epoch - 3ms/step
# Epoch 86/100
# 804/804 - 1s - loss: 0.5345 - accuracy: 0.7396 - 1s/epoch - 1ms/step
# Epoch 87/100
# 804/804 - 1s - loss: 0.5340 - accuracy: 0.7396 - 1s/epoch - 1ms/step
# Epoch 88/100
# 804/804 - 1s - loss: 0.5343 - accuracy: 0.7404 - 1s/epoch - 2ms/step
# Epoch 89/100
# 804/804 - 1s - loss: 0.5351 - accuracy: 0.7396 - 1s/epoch - 2ms/step
# Epoch 90/100
# 804/804 - 1s - loss: 0.5343 - accuracy: 0.7395 - 1s/epoch - 2ms/step
# Epoch 91/100
# 804/804 - 1s - loss: 0.5342 - accuracy: 0.7396 - 1s/epoch - 2ms/step
# Epoch 92/100
# 804/804 - 1s - loss: 0.5347 - accuracy: 0.7402 - 1s/epoch - 2ms/step
# Epoch 93/100
# 804/804 - 1s - loss: 0.5338 - accuracy: 0.7401 - 1s/epoch - 2ms/step
# Epoch 94/100
# 804/804 - 2s - loss: 0.5339 - accuracy: 0.7404 - 2s/epoch - 2ms/step
# Epoch 95/100
# 804/804 - 2s - loss: 0.5354 - accuracy: 0.7397 - 2s/epoch - 2ms/step
# Epoch 96/100
# 804/804 - 2s - loss: 0.5342 - accuracy: 0.7403 - 2s/epoch - 2ms/step
# Epoch 97/100
# 804/804 - 1s - loss: 0.5339 - accuracy: 0.7394 - 1s/epoch - 2ms/step
# Epoch 98/100
# 804/804 - 1s - loss: 0.5339 - accuracy: 0.7392 - 1s/epoch - 2ms/step
# Epoch 99/100
# 804/804 - 1s - loss: 0.5343 - accuracy: 0.7400 - 1s/epoch - 2ms/step
# Epoch 100/100
# 804/804 - 1s - loss: 0.5340 - accuracy: 0.7401 - 1s/epoch - 2ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5635 - accuracy: 0.7289 - 486ms/epoch - 2ms/step
# Loss: 0.5635281801223755, Accuracy: 0.728863000869751

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Additional Testing

# %% [markdown]
# Attempt #1 - Accuracy 72.85%, increase of 0.03% from original

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=6, input_dim=input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, verbose=2)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 804/804 - 3s - loss: 0.6314 - accuracy: 0.6668 - 3s/epoch - 4ms/step
# Epoch 2/100
# 804/804 - 1s - loss: 0.5728 - accuracy: 0.7240 - 1s/epoch - 1ms/step
# Epoch 3/100
# 804/804 - 1s - loss: 0.5655 - accuracy: 0.7278 - 1s/epoch - 2ms/step
# Epoch 4/100
# 804/804 - 1s - loss: 0.5618 - accuracy: 0.7283 - 1s/epoch - 1ms/step
# Epoch 5/100
# 804/804 - 1s - loss: 0.5591 - accuracy: 0.7296 - 1s/epoch - 2ms/step
# Epoch 6/100
# 804/804 - 1s - loss: 0.5576 - accuracy: 0.7294 - 1s/epoch - 2ms/step
# Epoch 7/100
# 804/804 - 1s - loss: 0.5567 - accuracy: 0.7308 - 1s/epoch - 2ms/step
# Epoch 8/100
# 804/804 - 1s - loss: 0.5558 - accuracy: 0.7302 - 1s/epoch - 1ms/step
# Epoch 9/100
# 804/804 - 1s - loss: 0.5552 - accuracy: 0.7308 - 1s/epoch - 2ms/step
# Epoch 10/100
# 804/804 - 2s - loss: 0.5545 - accuracy: 0.7309 - 2s/epoch - 2ms/step
# Epoch 11/100
# 804/804 - 2s - loss: 0.5539 - accuracy: 0.7309 - 2s/epoch - 2ms/step
# Epoch 12/100
# 804/804 - 2s - loss: 0.5533 - accuracy: 0.7304 - 2s/epoch - 2ms/step
# Epoch 13/100
# 804/804 - 1s - loss: 0.5529 - accuracy: 0.7322 - 1s/epoch - 2ms/step
# Epoch 14/100
# 804/804 - 1s - loss: 0.5527 - accuracy: 0.7314 - 1s/epoch - 2ms/step
# Epoch 15/100
# 804/804 - 1s - loss: 0.5525 - accuracy: 0.7314 - 1s/epoch - 1ms/step
# Epoch 16/100
# 804/804 - 1s - loss: 0.5521 - accuracy: 0.7312 - 1s/epoch - 1ms/step
# Epoch 17/100
# 804/804 - 1s - loss: 0.5517 - accuracy: 0.7314 - 1s/epoch - 2ms/step
# Epoch 18/100
# 804/804 - 1s - loss: 0.5516 - accuracy: 0.7308 - 1s/epoch - 1ms/step
# Epoch 19/100
# 804/804 - 1s - loss: 0.5512 - accuracy: 0.7310 - 1s/epoch - 1ms/step
# Epoch 20/100
# 804/804 - 1s - loss: 0.5513 - accuracy: 0.7324 - 1s/epoch - 2ms/step
# Epoch 21/100
# 804/804 - 2s - loss: 0.5510 - accuracy: 0.7312 - 2s/epoch - 2ms/step
# Epoch 22/100
# 804/804 - 2s - loss: 0.5509 - accuracy: 0.7311 - 2s/epoch - 2ms/step
# Epoch 23/100
# 804/804 - 2s - loss: 0.5503 - accuracy: 0.7306 - 2s/epoch - 2ms/step
# Epoch 24/100
# 804/804 - 1s - loss: 0.5501 - accuracy: 0.7308 - 1s/epoch - 1ms/step
# Epoch 25/100
# 804/804 - 1s - loss: 0.5497 - accuracy: 0.7320 - 1s/epoch - 2ms/step
# Epoch 26/100
# 804/804 - 1s - loss: 0.5497 - accuracy: 0.7319 - 1s/epoch - 1ms/step
# Epoch 27/100
# 804/804 - 1s - loss: 0.5497 - accuracy: 0.7328 - 1s/epoch - 2ms/step
# Epoch 28/100
# 804/804 - 1s - loss: 0.5496 - accuracy: 0.7320 - 1s/epoch - 1ms/step
# Epoch 29/100
# 804/804 - 1s - loss: 0.5495 - accuracy: 0.7310 - 1s/epoch - 2ms/step
# Epoch 30/100
# 804/804 - 1s - loss: 0.5494 - accuracy: 0.7307 - 1s/epoch - 1ms/step
# Epoch 31/100
# 804/804 - 1s - loss: 0.5493 - accuracy: 0.7321 - 1s/epoch - 1ms/step
# Epoch 32/100

# %% [markdown]
# Attempt #2 Accuracy 73.29%, increase of 0.45% from original

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=6, input_dim=input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, verbose=2)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %% [markdown]
# Attempt #3 Accuracy 73.00%, increase of 0.16% from the original

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=6, input_dim=input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=200, verbose=2)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
